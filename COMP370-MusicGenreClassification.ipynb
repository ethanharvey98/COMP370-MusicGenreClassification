# %% [markdown]
# # COMP370-MusicGenreClassification
# By Dr. Jonathan Hutchins and Ethan Harvey

# %% [markdown]
# ##### Description
# An overfitted neural network for music genre classification using MFCCs.

# %%
import os
# import librosa by typing "conda install -c conda-forge librosa" into anaconda prompt
# librosa is an audio and music processing package
import librosa
import math
import json
import numpy as np
from sklearn.model_selection import train_test_split
import tensorflow.keras as keras
import matplotlib.pyplot as plt

# %%
def save_mfcc(dataset_path, json_path, n_mfcc=13, n_fft=2048, hop_length=512, num_segments=5):
    
    # dictionary to store data
    data = {
        "mapping": [],
        "mfcc": [],
        "labels": []
    }

    num_samples_per_segment = int(SAMPLES_PER_TRACK/num_segments)
    expected_num_mfcc_vectors_per_segment = math.ceil(num_samples_per_segment/hop_length)

    # loop through all the genres
    for  i, (dirpath, dirnames, filenames) in enumerate(os.walk(dataset_path)):

        # ensure that we're not at the root level
        if dirpath is not dataset_path:

            #save the semantic label
            dirpath_components = dirpath.split("/") # genre/blues => ["genre", "blues"]
            semantic_label = dirpath_components[-1]
            data["mapping"].append(semantic_label)
            print("\nProcessing {}".format(semantic_label))

            #process files for a specific genre
            for f in filenames:

                # load the audio file
                file_path = os.path.join(dirpath, f)
                signal, sr = librosa.load(file_path, sr=SAMPLE_RATE)

                # process segments extracting mfcc and storing data
                for s in range(num_segments):
                    start_sample = num_samples_per_segment * s
                    finish_sample = start_sample + num_samples_per_segment

                    mfcc = librosa.feature.mfcc(signal[start_sample:finish_sample],
                                                sr = sr,
                                                n_fft=n_fft,
                                                n_mfcc=n_mfcc,
                                                hop_length=hop_length)

                    mfcc = mfcc.T

                    if len(mfcc)==expected_num_mfcc_vectors_per_segment:
                            data["mfcc"].append(mfcc.tolist())
                            data["labels"].append(i-1)
                            print("{}, segment{}".format(file_path, s+1))
                                                

    with open(json_path, "w") as fp:
        json.dump(data, fp, indent=4)

# %%
DATASET_PATH = "genre_dataset"
JSON_PATH = "data.json"
SAMPLE_RATE = 22050
DURATION = 30
SAMPLES_PER_TRACK = SAMPLE_RATE * DURATION
save_mfcc(DATASET_PATH, JSON_PATH, num_segments = 10)
# Out:
# Processing genre_dataset\blues
# genre_dataset\blues\blues.00000.wav, segment1
# genre_dataset\blues\blues.00000.wav, segment2
# genre_dataset\blues\blues.00000.wav, segment3
# genre_dataset\blues\blues.00000.wav, segment4
# genre_dataset\blues\blues.00000.wav, segment5
# genre_dataset\blues\blues.00000.wav, segment6
# genre_dataset\blues\blues.00000.wav, segment7
# genre_dataset\blues\blues.00000.wav, segment8
# genre_dataset\blues\blues.00000.wav, segment9
# genre_dataset\blues\blues.00000.wav, segment10
# genre_dataset\blues\blues.00001.wav, segment1
# genre_dataset\blues\blues.00001.wav, segment2
# genre_dataset\blues\blues.00001.wav, segment3
# genre_dataset\blues\blues.00001.wav, segment4
# genre_dataset\blues\blues.00001.wav, segment5
# genre_dataset\blues\blues.00001.wav, segment6
# genre_dataset\blues\blues.00001.wav, segment7
# genre_dataset\blues\blues.00001.wav, segment8
# genre_dataset\blues\blues.00001.wav, segment9
# genre_dataset\blues\blues.00001.wav, segment10
# genre_dataset\blues\blues.00002.wav, segment1
# genre_dataset\blues\blues.00002.wav, segment2
# genre_dataset\blues\blues.00002.wav, segment3
# genre_dataset\blues\blues.00002.wav, segment4
# genre_dataset\blues\blues.00002.wav, segment5
# genre_dataset\blues\blues.00002.wav, segment6
# genre_dataset\blues\blues.00002.wav, segment7
# genre_dataset\blues\blues.00002.wav, segment8
# genre_dataset\blues\blues.00002.wav, segment9
# genre_dataset\blues\blues.00002.wav, segment10
# genre_dataset\blues\blues.00003.wav, segment1
# genre_dataset\blues\blues.00003.wav, segment2
# genre_dataset\blues\blues.00003.wav, segment3
# genre_dataset\blues\blues.00003.wav, segment4
# genre_dataset\blues\blues.00003.wav, segment5
# genre_dataset\blues\blues.00003.wav, segment6
# genre_dataset\blues\blues.00003.wav, segment7
# genre_dataset\blues\blues.00003.wav, segment8
# genre_dataset\blues\blues.00003.wav, segment9
# genre_dataset\blues\blues.00003.wav, segment10
# genre_dataset\blues\blues.00004.wav, segment1
# genre_dataset\blues\blues.00004.wav, segment2
# genre_dataset\blues\blues.00004.wav, segment3
# genre_dataset\blues\blues.00004.wav, segment4
# genre_dataset\blues\blues.00004.wav, segment5
# genre_dataset\blues\blues.00004.wav, segment6
# genre_dataset\blues\blues.00004.wav, segment7
# genre_dataset\blues\blues.00004.wav, segment8
# genre_dataset\blues\blues.00004.wav, segment9
# genre_dataset\blues\blues.00004.wav, segment10
# genre_dataset\blues\blues.00005.wav, segment1
# genre_dataset\blues\blues.00005.wav, segment2
# genre_dataset\blues\blues.00005.wav, segment3
# genre_dataset\blues\blues.00005.wav, segment4
# genre_dataset\blues\blues.00005.wav, segment5
# genre_dataset\blues\blues.00005.wav, segment6
# genre_dataset\blues\blues.00005.wav, segment7
# genre_dataset\blues\blues.00005.wav, segment8
# genre_dataset\blues\blues.00005.wav, segment9
# genre_dataset\blues\blues.00005.wav, segment10
# genre_dataset\blues\blues.00006.wav, segment1
# genre_dataset\blues\blues.00006.wav, segment2
# genre_dataset\blues\blues.00006.wav, segment3
# genre_dataset\blues\blues.00006.wav, segment4
# genre_dataset\blues\blues.00006.wav, segment5
# genre_dataset\blues\blues.00006.wav, segment6
# genre_dataset\blues\blues.00006.wav, segment7
# genre_dataset\blues\blues.00006.wav, segment8
# genre_dataset\blues\blues.00006.wav, segment9
# genre_dataset\blues\blues.00006.wav, segment10
# genre_dataset\blues\blues.00007.wav, segment1
# genre_dataset\blues\blues.00007.wav, segment2
# genre_dataset\blues\blues.00007.wav, segment3
# genre_dataset\blues\blues.00007.wav, segment4
# genre_dataset\blues\blues.00007.wav, segment5
# genre_dataset\blues\blues.00007.wav, segment6
# genre_dataset\blues\blues.00007.wav, segment7
# genre_dataset\blues\blues.00007.wav, segment8
# genre_dataset\blues\blues.00007.wav, segment9
# genre_dataset\blues\blues.00007.wav, segment10
# genre_dataset\blues\blues.00008.wav, segment1
# genre_dataset\blues\blues.00008.wav, segment2
# genre_dataset\blues\blues.00008.wav, segment3
# genre_dataset\blues\blues.00008.wav, segment4
# genre_dataset\blues\blues.00008.wav, segment5
# genre_dataset\blues\blues.00008.wav, segment6
# genre_dataset\blues\blues.00008.wav, segment7
# genre_dataset\blues\blues.00008.wav, segment8
# genre_dataset\blues\blues.00008.wav, segment9
# genre_dataset\blues\blues.00008.wav, segment10
# genre_dataset\blues\blues.00009.wav, segment1
# genre_dataset\blues\blues.00009.wav, segment2
# genre_dataset\blues\blues.00009.wav, segment3
# genre_dataset\blues\blues.00009.wav, segment4
# genre_dataset\blues\blues.00009.wav, segment5
# genre_dataset\blues\blues.00009.wav, segment6
# genre_dataset\blues\blues.00009.wav, segment7
# genre_dataset\blues\blues.00009.wav, segment8
# genre_dataset\blues\blues.00009.wav, segment9
# genre_dataset\blues\blues.00009.wav, segment10
# genre_dataset\blues\blues.00010.wav, segment1
# genre_dataset\blues\blues.00010.wav, segment2
# genre_dataset\blues\blues.00010.wav, segment3
# genre_dataset\blues\blues.00010.wav, segment4
# genre_dataset\blues\blues.00010.wav, segment5
# genre_dataset\blues\blues.00010.wav, segment6
# genre_dataset\blues\blues.00010.wav, segment7
# genre_dataset\blues\blues.00010.wav, segment8
# genre_dataset\blues\blues.00010.wav, segment9
# genre_dataset\blues\blues.00010.wav, segment10
# genre_dataset\blues\blues.00011.wav, segment1
# genre_dataset\blues\blues.00011.wav, segment2
# genre_dataset\blues\blues.00011.wav, segment3
# genre_dataset\blues\blues.00011.wav, segment4
# genre_dataset\blues\blues.00011.wav, segment5
# genre_dataset\blues\blues.00011.wav, segment6
# genre_dataset\blues\blues.00011.wav, segment7
# genre_dataset\blues\blues.00011.wav, segment8
# genre_dataset\blues\blues.00011.wav, segment9
# genre_dataset\blues\blues.00011.wav, segment10
# genre_dataset\blues\blues.00012.wav, segment1
# genre_dataset\blues\blues.00012.wav, segment2
# genre_dataset\blues\blues.00012.wav, segment3
# genre_dataset\blues\blues.00012.wav, segment4
# genre_dataset\blues\blues.00012.wav, segment5
# genre_dataset\blues\blues.00012.wav, segment6
# genre_dataset\blues\blues.00012.wav, segment7
# genre_dataset\blues\blues.00012.wav, segment8
# genre_dataset\blues\blues.00012.wav, segment9
# genre_dataset\blues\blues.00012.wav, segment10
# genre_dataset\blues\blues.00013.wav, segment1
# genre_dataset\blues\blues.00013.wav, segment2
# genre_dataset\blues\blues.00013.wav, segment3
# genre_dataset\blues\blues.00013.wav, segment4
# genre_dataset\blues\blues.00013.wav, segment5
# genre_dataset\blues\blues.00013.wav, segment6
# genre_dataset\blues\blues.00013.wav, segment7
# genre_dataset\blues\blues.00013.wav, segment8
# genre_dataset\blues\blues.00013.wav, segment9
# genre_dataset\blues\blues.00013.wav, segment10
# genre_dataset\blues\blues.00014.wav, segment1
# genre_dataset\blues\blues.00014.wav, segment2
# genre_dataset\blues\blues.00014.wav, segment3
# genre_dataset\blues\blues.00014.wav, segment4
# genre_dataset\blues\blues.00014.wav, segment5
# genre_dataset\blues\blues.00014.wav, segment6
# genre_dataset\blues\blues.00014.wav, segment7
# genre_dataset\blues\blues.00014.wav, segment8
# genre_dataset\blues\blues.00014.wav, segment9
# genre_dataset\blues\blues.00014.wav, segment10
# genre_dataset\blues\blues.00015.wav, segment1
# genre_dataset\blues\blues.00015.wav, segment2
# genre_dataset\blues\blues.00015.wav, segment3
# genre_dataset\blues\blues.00015.wav, segment4
# genre_dataset\blues\blues.00015.wav, segment5
# genre_dataset\blues\blues.00015.wav, segment6
# genre_dataset\blues\blues.00015.wav, segment7
# genre_dataset\blues\blues.00015.wav, segment8
# genre_dataset\blues\blues.00015.wav, segment9
# genre_dataset\blues\blues.00015.wav, segment10
# genre_dataset\blues\blues.00016.wav, segment1
# genre_dataset\blues\blues.00016.wav, segment2
# genre_dataset\blues\blues.00016.wav, segment3
# genre_dataset\blues\blues.00016.wav, segment4
# genre_dataset\blues\blues.00016.wav, segment5
# genre_dataset\blues\blues.00016.wav, segment6
# genre_dataset\blues\blues.00016.wav, segment7
# genre_dataset\blues\blues.00016.wav, segment8
# genre_dataset\blues\blues.00016.wav, segment9
# genre_dataset\blues\blues.00016.wav, segment10
# genre_dataset\blues\blues.00017.wav, segment1
# genre_dataset\blues\blues.00017.wav, segment2
# genre_dataset\blues\blues.00017.wav, segment3
# genre_dataset\blues\blues.00017.wav, segment4
# genre_dataset\blues\blues.00017.wav, segment5
# genre_dataset\blues\blues.00017.wav, segment6
# genre_dataset\blues\blues.00017.wav, segment7
# genre_dataset\blues\blues.00017.wav, segment8
# genre_dataset\blues\blues.00017.wav, segment9
# genre_dataset\blues\blues.00017.wav, segment10
# genre_dataset\blues\blues.00018.wav, segment1
# genre_dataset\blues\blues.00018.wav, segment2
# genre_dataset\blues\blues.00018.wav, segment3
# genre_dataset\blues\blues.00018.wav, segment4
# genre_dataset\blues\blues.00018.wav, segment5
# genre_dataset\blues\blues.00018.wav, segment6
# genre_dataset\blues\blues.00018.wav, segment7
# genre_dataset\blues\blues.00018.wav, segment8
# genre_dataset\blues\blues.00018.wav, segment9
# genre_dataset\blues\blues.00018.wav, segment10
# genre_dataset\blues\blues.00019.wav, segment1
# genre_dataset\blues\blues.00019.wav, segment2
# genre_dataset\blues\blues.00019.wav, segment3
# genre_dataset\blues\blues.00019.wav, segment4
# genre_dataset\blues\blues.00019.wav, segment5
# genre_dataset\blues\blues.00019.wav, segment6
# genre_dataset\blues\blues.00019.wav, segment7
# genre_dataset\blues\blues.00019.wav, segment8
# genre_dataset\blues\blues.00019.wav, segment9
# genre_dataset\blues\blues.00019.wav, segment10
# genre_dataset\blues\blues.00020.wav, segment1
# genre_dataset\blues\blues.00020.wav, segment2
# genre_dataset\blues\blues.00020.wav, segment3
# genre_dataset\blues\blues.00020.wav, segment4
# genre_dataset\blues\blues.00020.wav, segment5
# genre_dataset\blues\blues.00020.wav, segment6
# genre_dataset\blues\blues.00020.wav, segment7
# genre_dataset\blues\blues.00020.wav, segment8
# genre_dataset\blues\blues.00020.wav, segment9
# genre_dataset\blues\blues.00020.wav, segment10
# genre_dataset\blues\blues.00021.wav, segment1
# genre_dataset\blues\blues.00021.wav, segment2
# genre_dataset\blues\blues.00021.wav, segment3
# genre_dataset\blues\blues.00021.wav, segment4
# genre_dataset\blues\blues.00021.wav, segment5
# genre_dataset\blues\blues.00021.wav, segment6
# genre_dataset\blues\blues.00021.wav, segment7
# genre_dataset\blues\blues.00021.wav, segment8
# genre_dataset\blues\blues.00021.wav, segment9
# genre_dataset\blues\blues.00021.wav, segment10
# genre_dataset\blues\blues.00022.wav, segment1
# genre_dataset\blues\blues.00022.wav, segment2
# genre_dataset\blues\blues.00022.wav, segment3
# genre_dataset\blues\blues.00022.wav, segment4
# genre_dataset\blues\blues.00022.wav, segment5
# genre_dataset\blues\blues.00022.wav, segment6
# genre_dataset\blues\blues.00022.wav, segment7
# genre_dataset\blues\blues.00022.wav, segment8
# genre_dataset\blues\blues.00022.wav, segment9
# genre_dataset\blues\blues.00022.wav, segment10
# genre_dataset\blues\blues.00023.wav, segment1
# genre_dataset\blues\blues.00023.wav, segment2
# genre_dataset\blues\blues.00023.wav, segment3
# genre_dataset\blues\blues.00023.wav, segment4
# genre_dataset\blues\blues.00023.wav, segment5
# genre_dataset\blues\blues.00023.wav, segment6
# genre_dataset\blues\blues.00023.wav, segment7
# genre_dataset\blues\blues.00023.wav, segment8
# genre_dataset\blues\blues.00023.wav, segment9
# genre_dataset\blues\blues.00023.wav, segment10
# genre_dataset\blues\blues.00024.wav, segment1
# genre_dataset\blues\blues.00024.wav, segment2
# genre_dataset\blues\blues.00024.wav, segment3
# genre_dataset\blues\blues.00024.wav, segment4
# genre_dataset\blues\blues.00024.wav, segment5
# genre_dataset\blues\blues.00024.wav, segment6
# genre_dataset\blues\blues.00024.wav, segment7
# genre_dataset\blues\blues.00024.wav, segment8
# genre_dataset\blues\blues.00024.wav, segment9
# genre_dataset\blues\blues.00024.wav, segment10
# genre_dataset\blues\blues.00025.wav, segment1
# genre_dataset\blues\blues.00025.wav, segment2
# genre_dataset\blues\blues.00025.wav, segment3
# genre_dataset\blues\blues.00025.wav, segment4
# genre_dataset\blues\blues.00025.wav, segment5
# genre_dataset\blues\blues.00025.wav, segment6
# genre_dataset\blues\blues.00025.wav, segment7
# genre_dataset\blues\blues.00025.wav, segment8
# genre_dataset\blues\blues.00025.wav, segment9
# genre_dataset\blues\blues.00025.wav, segment10
# genre_dataset\blues\blues.00026.wav, segment1
# genre_dataset\blues\blues.00026.wav, segment2
# genre_dataset\blues\blues.00026.wav, segment3
# genre_dataset\blues\blues.00026.wav, segment4
# genre_dataset\blues\blues.00026.wav, segment5
# genre_dataset\blues\blues.00026.wav, segment6
# genre_dataset\blues\blues.00026.wav, segment7
# genre_dataset\blues\blues.00026.wav, segment8
# genre_dataset\blues\blues.00026.wav, segment9
# genre_dataset\blues\blues.00026.wav, segment10
# genre_dataset\blues\blues.00027.wav, segment1
# genre_dataset\blues\blues.00027.wav, segment2
# genre_dataset\blues\blues.00027.wav, segment3
# genre_dataset\blues\blues.00027.wav, segment4
# genre_dataset\blues\blues.00027.wav, segment5
# genre_dataset\blues\blues.00027.wav, segment6
# genre_dataset\blues\blues.00027.wav, segment7
# genre_dataset\blues\blues.00027.wav, segment8
# genre_dataset\blues\blues.00027.wav, segment9
# genre_dataset\blues\blues.00027.wav, segment10
# genre_dataset\blues\blues.00028.wav, segment1
# genre_dataset\blues\blues.00028.wav, segment2
# genre_dataset\blues\blues.00028.wav, segment3
# genre_dataset\blues\blues.00028.wav, segment4
# genre_dataset\blues\blues.00028.wav, segment5
# genre_dataset\blues\blues.00028.wav, segment6
# genre_dataset\blues\blues.00028.wav, segment7
# genre_dataset\blues\blues.00028.wav, segment8
# genre_dataset\blues\blues.00028.wav, segment9
# genre_dataset\blues\blues.00028.wav, segment10
# genre_dataset\blues\blues.00029.wav, segment1
# genre_dataset\blues\blues.00029.wav, segment2
# genre_dataset\blues\blues.00029.wav, segment3
# genre_dataset\blues\blues.00029.wav, segment4
# genre_dataset\blues\blues.00029.wav, segment5
# genre_dataset\blues\blues.00029.wav, segment6
# genre_dataset\blues\blues.00029.wav, segment7
# genre_dataset\blues\blues.00029.wav, segment8
# genre_dataset\blues\blues.00029.wav, segment9
# genre_dataset\blues\blues.00029.wav, segment10
# genre_dataset\blues\blues.00030.wav, segment1
# genre_dataset\blues\blues.00030.wav, segment2
# genre_dataset\blues\blues.00030.wav, segment3
# genre_dataset\blues\blues.00030.wav, segment4
# genre_dataset\blues\blues.00030.wav, segment5
# genre_dataset\blues\blues.00030.wav, segment6
# genre_dataset\blues\blues.00030.wav, segment7
# genre_dataset\blues\blues.00030.wav, segment8
# genre_dataset\blues\blues.00030.wav, segment9
# genre_dataset\blues\blues.00030.wav, segment10
# genre_dataset\blues\blues.00031.wav, segment1
# genre_dataset\blues\blues.00031.wav, segment2
# genre_dataset\blues\blues.00031.wav, segment3
# genre_dataset\blues\blues.00031.wav, segment4
# genre_dataset\blues\blues.00031.wav, segment5
# genre_dataset\blues\blues.00031.wav, segment6
# genre_dataset\blues\blues.00031.wav, segment7
# genre_dataset\blues\blues.00031.wav, segment8
# genre_dataset\blues\blues.00031.wav, segment9
# genre_dataset\blues\blues.00031.wav, segment10
# genre_dataset\blues\blues.00032.wav, segment1
# genre_dataset\blues\blues.00032.wav, segment2
# genre_dataset\blues\blues.00032.wav, segment3
# genre_dataset\blues\blues.00032.wav, segment4
# genre_dataset\blues\blues.00032.wav, segment5
# genre_dataset\blues\blues.00032.wav, segment6
# genre_dataset\blues\blues.00032.wav, segment7
# genre_dataset\blues\blues.00032.wav, segment8
# genre_dataset\blues\blues.00032.wav, segment9
# genre_dataset\blues\blues.00032.wav, segment10
# genre_dataset\blues\blues.00033.wav, segment1
# genre_dataset\blues\blues.00033.wav, segment2
# genre_dataset\blues\blues.00033.wav, segment3
# genre_dataset\blues\blues.00033.wav, segment4
# genre_dataset\blues\blues.00033.wav, segment5
# genre_dataset\blues\blues.00033.wav, segment6
# genre_dataset\blues\blues.00033.wav, segment7
# genre_dataset\blues\blues.00033.wav, segment8
# genre_dataset\blues\blues.00033.wav, segment9
# genre_dataset\blues\blues.00033.wav, segment10
# genre_dataset\blues\blues.00034.wav, segment1
# genre_dataset\blues\blues.00034.wav, segment2
# genre_dataset\blues\blues.00034.wav, segment3
# genre_dataset\blues\blues.00034.wav, segment4
# genre_dataset\blues\blues.00034.wav, segment5
# genre_dataset\blues\blues.00034.wav, segment6
# genre_dataset\blues\blues.00034.wav, segment7
# genre_dataset\blues\blues.00034.wav, segment8
# genre_dataset\blues\blues.00034.wav, segment9
# genre_dataset\blues\blues.00034.wav, segment10
# genre_dataset\blues\blues.00035.wav, segment1
# genre_dataset\blues\blues.00035.wav, segment2
# genre_dataset\blues\blues.00035.wav, segment3
# genre_dataset\blues\blues.00035.wav, segment4
# genre_dataset\blues\blues.00035.wav, segment5
# genre_dataset\blues\blues.00035.wav, segment6
# genre_dataset\blues\blues.00035.wav, segment7
# genre_dataset\blues\blues.00035.wav, segment8
# genre_dataset\blues\blues.00035.wav, segment9
# genre_dataset\blues\blues.00035.wav, segment10
# genre_dataset\blues\blues.00036.wav, segment1
# genre_dataset\blues\blues.00036.wav, segment2
# genre_dataset\blues\blues.00036.wav, segment3
# genre_dataset\blues\blues.00036.wav, segment4
# genre_dataset\blues\blues.00036.wav, segment5
# genre_dataset\blues\blues.00036.wav, segment6
# genre_dataset\blues\blues.00036.wav, segment7
# genre_dataset\blues\blues.00036.wav, segment8
# genre_dataset\blues\blues.00036.wav, segment9
# genre_dataset\blues\blues.00036.wav, segment10
# genre_dataset\blues\blues.00037.wav, segment1
# genre_dataset\blues\blues.00037.wav, segment2
# genre_dataset\blues\blues.00037.wav, segment3
# genre_dataset\blues\blues.00037.wav, segment4
# genre_dataset\blues\blues.00037.wav, segment5
# genre_dataset\blues\blues.00037.wav, segment6
# genre_dataset\blues\blues.00037.wav, segment7
# genre_dataset\blues\blues.00037.wav, segment8
# genre_dataset\blues\blues.00037.wav, segment9
# genre_dataset\blues\blues.00037.wav, segment10
# genre_dataset\blues\blues.00038.wav, segment1
# genre_dataset\blues\blues.00038.wav, segment2
# genre_dataset\blues\blues.00038.wav, segment3
# genre_dataset\blues\blues.00038.wav, segment4
# genre_dataset\blues\blues.00038.wav, segment5
# genre_dataset\blues\blues.00038.wav, segment6
# genre_dataset\blues\blues.00038.wav, segment7
# genre_dataset\blues\blues.00038.wav, segment8
# genre_dataset\blues\blues.00038.wav, segment9
# genre_dataset\blues\blues.00038.wav, segment10
# genre_dataset\blues\blues.00039.wav, segment1
# genre_dataset\blues\blues.00039.wav, segment2
# genre_dataset\blues\blues.00039.wav, segment3
# genre_dataset\blues\blues.00039.wav, segment4
# genre_dataset\blues\blues.00039.wav, segment5
# genre_dataset\blues\blues.00039.wav, segment6
# genre_dataset\blues\blues.00039.wav, segment7
# genre_dataset\blues\blues.00039.wav, segment8
# genre_dataset\blues\blues.00039.wav, segment9
# genre_dataset\blues\blues.00039.wav, segment10
# genre_dataset\blues\blues.00040.wav, segment1
# genre_dataset\blues\blues.00040.wav, segment2
# genre_dataset\blues\blues.00040.wav, segment3
# genre_dataset\blues\blues.00040.wav, segment4
# genre_dataset\blues\blues.00040.wav, segment5
# genre_dataset\blues\blues.00040.wav, segment6
# genre_dataset\blues\blues.00040.wav, segment7
# genre_dataset\blues\blues.00040.wav, segment8
# genre_dataset\blues\blues.00040.wav, segment9
# genre_dataset\blues\blues.00040.wav, segment10
# genre_dataset\blues\blues.00041.wav, segment1
# genre_dataset\blues\blues.00041.wav, segment2
# genre_dataset\blues\blues.00041.wav, segment3
# genre_dataset\blues\blues.00041.wav, segment4
# genre_dataset\blues\blues.00041.wav, segment5
# genre_dataset\blues\blues.00041.wav, segment6
# genre_dataset\blues\blues.00041.wav, segment7
# genre_dataset\blues\blues.00041.wav, segment8
# genre_dataset\blues\blues.00041.wav, segment9
# genre_dataset\blues\blues.00041.wav, segment10
# genre_dataset\blues\blues.00042.wav, segment1
# genre_dataset\blues\blues.00042.wav, segment2
# genre_dataset\blues\blues.00042.wav, segment3
# genre_dataset\blues\blues.00042.wav, segment4
# genre_dataset\blues\blues.00042.wav, segment5
# genre_dataset\blues\blues.00042.wav, segment6
# genre_dataset\blues\blues.00042.wav, segment7
# genre_dataset\blues\blues.00042.wav, segment8
# genre_dataset\blues\blues.00042.wav, segment9
# genre_dataset\blues\blues.00042.wav, segment10
# genre_dataset\blues\blues.00043.wav, segment1
# genre_dataset\blues\blues.00043.wav, segment2
# genre_dataset\blues\blues.00043.wav, segment3
# genre_dataset\blues\blues.00043.wav, segment4
# genre_dataset\blues\blues.00043.wav, segment5
# genre_dataset\blues\blues.00043.wav, segment6
# genre_dataset\blues\blues.00043.wav, segment7
# genre_dataset\blues\blues.00043.wav, segment8
# genre_dataset\blues\blues.00043.wav, segment9
# genre_dataset\blues\blues.00043.wav, segment10
# genre_dataset\blues\blues.00044.wav, segment1
# genre_dataset\blues\blues.00044.wav, segment2
# genre_dataset\blues\blues.00044.wav, segment3
# genre_dataset\blues\blues.00044.wav, segment4
# genre_dataset\blues\blues.00044.wav, segment5
# genre_dataset\blues\blues.00044.wav, segment6
# genre_dataset\blues\blues.00044.wav, segment7
# genre_dataset\blues\blues.00044.wav, segment8
# genre_dataset\blues\blues.00044.wav, segment9
# genre_dataset\blues\blues.00044.wav, segment10
# genre_dataset\blues\blues.00045.wav, segment1
# genre_dataset\blues\blues.00045.wav, segment2
# genre_dataset\blues\blues.00045.wav, segment3
# genre_dataset\blues\blues.00045.wav, segment4
# genre_dataset\blues\blues.00045.wav, segment5
# genre_dataset\blues\blues.00045.wav, segment6
# genre_dataset\blues\blues.00045.wav, segment7
# genre_dataset\blues\blues.00045.wav, segment8
# genre_dataset\blues\blues.00045.wav, segment9
# genre_dataset\blues\blues.00045.wav, segment10
# genre_dataset\blues\blues.00046.wav, segment1
# genre_dataset\blues\blues.00046.wav, segment2
# genre_dataset\blues\blues.00046.wav, segment3
# genre_dataset\blues\blues.00046.wav, segment4
# genre_dataset\blues\blues.00046.wav, segment5
# genre_dataset\blues\blues.00046.wav, segment6
# genre_dataset\blues\blues.00046.wav, segment7
# genre_dataset\blues\blues.00046.wav, segment8
# genre_dataset\blues\blues.00046.wav, segment9
# genre_dataset\blues\blues.00046.wav, segment10
# genre_dataset\blues\blues.00047.wav, segment1
# genre_dataset\blues\blues.00047.wav, segment2
# genre_dataset\blues\blues.00047.wav, segment3
# genre_dataset\blues\blues.00047.wav, segment4
# genre_dataset\blues\blues.00047.wav, segment5
# genre_dataset\blues\blues.00047.wav, segment6
# genre_dataset\blues\blues.00047.wav, segment7
# genre_dataset\blues\blues.00047.wav, segment8
# genre_dataset\blues\blues.00047.wav, segment9
# genre_dataset\blues\blues.00047.wav, segment10
# genre_dataset\blues\blues.00048.wav, segment1
# genre_dataset\blues\blues.00048.wav, segment2
# genre_dataset\blues\blues.00048.wav, segment3
# genre_dataset\blues\blues.00048.wav, segment4
# genre_dataset\blues\blues.00048.wav, segment5
# genre_dataset\blues\blues.00048.wav, segment6
# genre_dataset\blues\blues.00048.wav, segment7
# genre_dataset\blues\blues.00048.wav, segment8
# genre_dataset\blues\blues.00048.wav, segment9
# genre_dataset\blues\blues.00048.wav, segment10
# genre_dataset\blues\blues.00049.wav, segment1
# genre_dataset\blues\blues.00049.wav, segment2
# genre_dataset\blues\blues.00049.wav, segment3
# genre_dataset\blues\blues.00049.wav, segment4
# genre_dataset\blues\blues.00049.wav, segment5
# genre_dataset\blues\blues.00049.wav, segment6
# genre_dataset\blues\blues.00049.wav, segment7
# genre_dataset\blues\blues.00049.wav, segment8
# genre_dataset\blues\blues.00049.wav, segment9
# genre_dataset\blues\blues.00049.wav, segment10
# genre_dataset\blues\blues.00050.wav, segment1
# genre_dataset\blues\blues.00050.wav, segment2
# genre_dataset\blues\blues.00050.wav, segment3
# genre_dataset\blues\blues.00050.wav, segment4
# genre_dataset\blues\blues.00050.wav, segment5
# genre_dataset\blues\blues.00050.wav, segment6
# genre_dataset\blues\blues.00050.wav, segment7
# genre_dataset\blues\blues.00050.wav, segment8
# genre_dataset\blues\blues.00050.wav, segment9
# genre_dataset\blues\blues.00050.wav, segment10
# genre_dataset\blues\blues.00051.wav, segment1
# genre_dataset\blues\blues.00051.wav, segment2
# genre_dataset\blues\blues.00051.wav, segment3
# genre_dataset\blues\blues.00051.wav, segment4
# genre_dataset\blues\blues.00051.wav, segment5
# genre_dataset\blues\blues.00051.wav, segment6
# genre_dataset\blues\blues.00051.wav, segment7
# genre_dataset\blues\blues.00051.wav, segment8
# genre_dataset\blues\blues.00051.wav, segment9
# genre_dataset\blues\blues.00051.wav, segment10
# genre_dataset\blues\blues.00052.wav, segment1
# genre_dataset\blues\blues.00052.wav, segment2
# genre_dataset\blues\blues.00052.wav, segment3
# genre_dataset\blues\blues.00052.wav, segment4
# genre_dataset\blues\blues.00052.wav, segment5
# genre_dataset\blues\blues.00052.wav, segment6
# genre_dataset\blues\blues.00052.wav, segment7
# genre_dataset\blues\blues.00052.wav, segment8
# genre_dataset\blues\blues.00052.wav, segment9
# genre_dataset\blues\blues.00052.wav, segment10
# genre_dataset\blues\blues.00053.wav, segment1
# genre_dataset\blues\blues.00053.wav, segment2
# genre_dataset\blues\blues.00053.wav, segment3
# genre_dataset\blues\blues.00053.wav, segment4
# genre_dataset\blues\blues.00053.wav, segment5
# genre_dataset\blues\blues.00053.wav, segment6
# genre_dataset\blues\blues.00053.wav, segment7
# genre_dataset\blues\blues.00053.wav, segment8
# genre_dataset\blues\blues.00053.wav, segment9
# genre_dataset\blues\blues.00053.wav, segment10
# genre_dataset\blues\blues.00054.wav, segment1
# genre_dataset\blues\blues.00054.wav, segment2
# genre_dataset\blues\blues.00054.wav, segment3
# genre_dataset\blues\blues.00054.wav, segment4
# genre_dataset\blues\blues.00054.wav, segment5
# genre_dataset\blues\blues.00054.wav, segment6
# genre_dataset\blues\blues.00054.wav, segment7
# genre_dataset\blues\blues.00054.wav, segment8
# genre_dataset\blues\blues.00054.wav, segment9
# genre_dataset\blues\blues.00054.wav, segment10
# genre_dataset\blues\blues.00055.wav, segment1
# genre_dataset\blues\blues.00055.wav, segment2
# genre_dataset\blues\blues.00055.wav, segment3
# genre_dataset\blues\blues.00055.wav, segment4
# genre_dataset\blues\blues.00055.wav, segment5
# genre_dataset\blues\blues.00055.wav, segment6
# genre_dataset\blues\blues.00055.wav, segment7
# genre_dataset\blues\blues.00055.wav, segment8
# genre_dataset\blues\blues.00055.wav, segment9
# genre_dataset\blues\blues.00055.wav, segment10
# genre_dataset\blues\blues.00056.wav, segment1
# genre_dataset\blues\blues.00056.wav, segment2
# genre_dataset\blues\blues.00056.wav, segment3
# genre_dataset\blues\blues.00056.wav, segment4
# genre_dataset\blues\blues.00056.wav, segment5
# genre_dataset\blues\blues.00056.wav, segment6
# genre_dataset\blues\blues.00056.wav, segment7
# genre_dataset\blues\blues.00056.wav, segment8
# genre_dataset\blues\blues.00056.wav, segment9
# genre_dataset\blues\blues.00056.wav, segment10
# genre_dataset\blues\blues.00057.wav, segment1
# genre_dataset\blues\blues.00057.wav, segment2
# genre_dataset\blues\blues.00057.wav, segment3
# genre_dataset\blues\blues.00057.wav, segment4
# genre_dataset\blues\blues.00057.wav, segment5
# genre_dataset\blues\blues.00057.wav, segment6
# genre_dataset\blues\blues.00057.wav, segment7
# genre_dataset\blues\blues.00057.wav, segment8
# genre_dataset\blues\blues.00057.wav, segment9
# genre_dataset\blues\blues.00057.wav, segment10
# genre_dataset\blues\blues.00058.wav, segment1
# genre_dataset\blues\blues.00058.wav, segment2
# genre_dataset\blues\blues.00058.wav, segment3
# genre_dataset\blues\blues.00058.wav, segment4
# genre_dataset\blues\blues.00058.wav, segment5
# genre_dataset\blues\blues.00058.wav, segment6
# genre_dataset\blues\blues.00058.wav, segment7
# genre_dataset\blues\blues.00058.wav, segment8
# genre_dataset\blues\blues.00058.wav, segment9
# genre_dataset\blues\blues.00058.wav, segment10
# genre_dataset\blues\blues.00059.wav, segment1
# genre_dataset\blues\blues.00059.wav, segment2
# genre_dataset\blues\blues.00059.wav, segment3
# genre_dataset\blues\blues.00059.wav, segment4
# genre_dataset\blues\blues.00059.wav, segment5
# genre_dataset\blues\blues.00059.wav, segment6
# genre_dataset\blues\blues.00059.wav, segment7
# genre_dataset\blues\blues.00059.wav, segment8
# genre_dataset\blues\blues.00059.wav, segment9
# genre_dataset\blues\blues.00059.wav, segment10
# genre_dataset\blues\blues.00060.wav, segment1
# genre_dataset\blues\blues.00060.wav, segment2
# genre_dataset\blues\blues.00060.wav, segment3
# genre_dataset\blues\blues.00060.wav, segment4
# genre_dataset\blues\blues.00060.wav, segment5
# genre_dataset\blues\blues.00060.wav, segment6
# genre_dataset\blues\blues.00060.wav, segment7
# genre_dataset\blues\blues.00060.wav, segment8
# genre_dataset\blues\blues.00060.wav, segment9
# genre_dataset\blues\blues.00060.wav, segment10
# genre_dataset\blues\blues.00061.wav, segment1
# genre_dataset\blues\blues.00061.wav, segment2
# genre_dataset\blues\blues.00061.wav, segment3
# genre_dataset\blues\blues.00061.wav, segment4
# genre_dataset\blues\blues.00061.wav, segment5
# genre_dataset\blues\blues.00061.wav, segment6
# genre_dataset\blues\blues.00061.wav, segment7
# genre_dataset\blues\blues.00061.wav, segment8
# genre_dataset\blues\blues.00061.wav, segment9
# genre_dataset\blues\blues.00061.wav, segment10
# genre_dataset\blues\blues.00062.wav, segment1
# genre_dataset\blues\blues.00062.wav, segment2
# genre_dataset\blues\blues.00062.wav, segment3
# genre_dataset\blues\blues.00062.wav, segment4
# genre_dataset\blues\blues.00062.wav, segment5
# genre_dataset\blues\blues.00062.wav, segment6
# genre_dataset\blues\blues.00062.wav, segment7
# genre_dataset\blues\blues.00062.wav, segment8
# genre_dataset\blues\blues.00062.wav, segment9
# genre_dataset\blues\blues.00062.wav, segment10
# genre_dataset\blues\blues.00063.wav, segment1
# genre_dataset\blues\blues.00063.wav, segment2
# genre_dataset\blues\blues.00063.wav, segment3
# genre_dataset\blues\blues.00063.wav, segment4
# genre_dataset\blues\blues.00063.wav, segment5
# genre_dataset\blues\blues.00063.wav, segment6
# genre_dataset\blues\blues.00063.wav, segment7
# genre_dataset\blues\blues.00063.wav, segment8
# genre_dataset\blues\blues.00063.wav, segment9
# genre_dataset\blues\blues.00063.wav, segment10
# genre_dataset\blues\blues.00064.wav, segment1
# genre_dataset\blues\blues.00064.wav, segment2
# genre_dataset\blues\blues.00064.wav, segment3
# genre_dataset\blues\blues.00064.wav, segment4
# genre_dataset\blues\blues.00064.wav, segment5
# genre_dataset\blues\blues.00064.wav, segment6
# genre_dataset\blues\blues.00064.wav, segment7
# genre_dataset\blues\blues.00064.wav, segment8
# genre_dataset\blues\blues.00064.wav, segment9
# genre_dataset\blues\blues.00064.wav, segment10
# genre_dataset\blues\blues.00065.wav, segment1
# genre_dataset\blues\blues.00065.wav, segment2
# genre_dataset\blues\blues.00065.wav, segment3
# genre_dataset\blues\blues.00065.wav, segment4
# genre_dataset\blues\blues.00065.wav, segment5
# genre_dataset\blues\blues.00065.wav, segment6
# genre_dataset\blues\blues.00065.wav, segment7
# genre_dataset\blues\blues.00065.wav, segment8
# genre_dataset\blues\blues.00065.wav, segment9
# genre_dataset\blues\blues.00065.wav, segment10
# genre_dataset\blues\blues.00066.wav, segment1
# genre_dataset\blues\blues.00066.wav, segment2
# genre_dataset\blues\blues.00066.wav, segment3
# genre_dataset\blues\blues.00066.wav, segment4
# genre_dataset\blues\blues.00066.wav, segment5
# genre_dataset\blues\blues.00066.wav, segment6
# genre_dataset\blues\blues.00066.wav, segment7
# genre_dataset\blues\blues.00066.wav, segment8
# genre_dataset\blues\blues.00066.wav, segment9
# genre_dataset\blues\blues.00066.wav, segment10
# genre_dataset\blues\blues.00067.wav, segment1
# genre_dataset\blues\blues.00067.wav, segment2
# genre_dataset\blues\blues.00067.wav, segment3
# genre_dataset\blues\blues.00067.wav, segment4
# genre_dataset\blues\blues.00067.wav, segment5
# genre_dataset\blues\blues.00067.wav, segment6
# genre_dataset\blues\blues.00067.wav, segment7
# genre_dataset\blues\blues.00067.wav, segment8
# genre_dataset\blues\blues.00067.wav, segment9
# genre_dataset\blues\blues.00067.wav, segment10
# genre_dataset\blues\blues.00068.wav, segment1
# genre_dataset\blues\blues.00068.wav, segment2
# genre_dataset\blues\blues.00068.wav, segment3
# genre_dataset\blues\blues.00068.wav, segment4
# genre_dataset\blues\blues.00068.wav, segment5
# genre_dataset\blues\blues.00068.wav, segment6
# genre_dataset\blues\blues.00068.wav, segment7
# genre_dataset\blues\blues.00068.wav, segment8
# genre_dataset\blues\blues.00068.wav, segment9
# genre_dataset\blues\blues.00068.wav, segment10
# genre_dataset\blues\blues.00069.wav, segment1
# genre_dataset\blues\blues.00069.wav, segment2
# genre_dataset\blues\blues.00069.wav, segment3
# genre_dataset\blues\blues.00069.wav, segment4
# genre_dataset\blues\blues.00069.wav, segment5
# genre_dataset\blues\blues.00069.wav, segment6
# genre_dataset\blues\blues.00069.wav, segment7
# genre_dataset\blues\blues.00069.wav, segment8
# genre_dataset\blues\blues.00069.wav, segment9
# genre_dataset\blues\blues.00069.wav, segment10
# genre_dataset\blues\blues.00070.wav, segment1
# genre_dataset\blues\blues.00070.wav, segment2
# genre_dataset\blues\blues.00070.wav, segment3
# genre_dataset\blues\blues.00070.wav, segment4
# genre_dataset\blues\blues.00070.wav, segment5
# genre_dataset\blues\blues.00070.wav, segment6
# genre_dataset\blues\blues.00070.wav, segment7
# genre_dataset\blues\blues.00070.wav, segment8
# genre_dataset\blues\blues.00070.wav, segment9
# genre_dataset\blues\blues.00070.wav, segment10
# genre_dataset\blues\blues.00071.wav, segment1
# genre_dataset\blues\blues.00071.wav, segment2
# genre_dataset\blues\blues.00071.wav, segment3
# genre_dataset\blues\blues.00071.wav, segment4
# genre_dataset\blues\blues.00071.wav, segment5
# genre_dataset\blues\blues.00071.wav, segment6
# genre_dataset\blues\blues.00071.wav, segment7
# genre_dataset\blues\blues.00071.wav, segment8
# genre_dataset\blues\blues.00071.wav, segment9
# genre_dataset\blues\blues.00071.wav, segment10
# genre_dataset\blues\blues.00072.wav, segment1
# genre_dataset\blues\blues.00072.wav, segment2
# genre_dataset\blues\blues.00072.wav, segment3
# genre_dataset\blues\blues.00072.wav, segment4
# genre_dataset\blues\blues.00072.wav, segment5
# genre_dataset\blues\blues.00072.wav, segment6
# genre_dataset\blues\blues.00072.wav, segment7
# genre_dataset\blues\blues.00072.wav, segment8
# genre_dataset\blues\blues.00072.wav, segment9
# genre_dataset\blues\blues.00072.wav, segment10
# genre_dataset\blues\blues.00073.wav, segment1
# genre_dataset\blues\blues.00073.wav, segment2
# genre_dataset\blues\blues.00073.wav, segment3
# genre_dataset\blues\blues.00073.wav, segment4
# genre_dataset\blues\blues.00073.wav, segment5
# genre_dataset\blues\blues.00073.wav, segment6
# genre_dataset\blues\blues.00073.wav, segment7
# genre_dataset\blues\blues.00073.wav, segment8
# genre_dataset\blues\blues.00073.wav, segment9
# genre_dataset\blues\blues.00073.wav, segment10
# genre_dataset\blues\blues.00074.wav, segment1
# genre_dataset\blues\blues.00074.wav, segment2
# genre_dataset\blues\blues.00074.wav, segment3
# genre_dataset\blues\blues.00074.wav, segment4
# genre_dataset\blues\blues.00074.wav, segment5
# genre_dataset\blues\blues.00074.wav, segment6
# genre_dataset\blues\blues.00074.wav, segment7
# genre_dataset\blues\blues.00074.wav, segment8
# genre_dataset\blues\blues.00074.wav, segment9
# genre_dataset\blues\blues.00074.wav, segment10
# genre_dataset\blues\blues.00075.wav, segment1
# genre_dataset\blues\blues.00075.wav, segment2
# genre_dataset\blues\blues.00075.wav, segment3
# genre_dataset\blues\blues.00075.wav, segment4
# genre_dataset\blues\blues.00075.wav, segment5
# genre_dataset\blues\blues.00075.wav, segment6
# genre_dataset\blues\blues.00075.wav, segment7
# genre_dataset\blues\blues.00075.wav, segment8
# genre_dataset\blues\blues.00075.wav, segment9
# genre_dataset\blues\blues.00075.wav, segment10
# genre_dataset\blues\blues.00076.wav, segment1
# genre_dataset\blues\blues.00076.wav, segment2
# genre_dataset\blues\blues.00076.wav, segment3
# genre_dataset\blues\blues.00076.wav, segment4
# genre_dataset\blues\blues.00076.wav, segment5
# genre_dataset\blues\blues.00076.wav, segment6
# genre_dataset\blues\blues.00076.wav, segment7
# genre_dataset\blues\blues.00076.wav, segment8
# genre_dataset\blues\blues.00076.wav, segment9
# genre_dataset\blues\blues.00076.wav, segment10
# genre_dataset\blues\blues.00077.wav, segment1
# genre_dataset\blues\blues.00077.wav, segment2
# genre_dataset\blues\blues.00077.wav, segment3
# genre_dataset\blues\blues.00077.wav, segment4
# genre_dataset\blues\blues.00077.wav, segment5
# genre_dataset\blues\blues.00077.wav, segment6
# genre_dataset\blues\blues.00077.wav, segment7
# genre_dataset\blues\blues.00077.wav, segment8
# genre_dataset\blues\blues.00077.wav, segment9
# genre_dataset\blues\blues.00077.wav, segment10
# genre_dataset\blues\blues.00078.wav, segment1
# genre_dataset\blues\blues.00078.wav, segment2
# genre_dataset\blues\blues.00078.wav, segment3
# genre_dataset\blues\blues.00078.wav, segment4
# genre_dataset\blues\blues.00078.wav, segment5
# genre_dataset\blues\blues.00078.wav, segment6
# genre_dataset\blues\blues.00078.wav, segment7
# genre_dataset\blues\blues.00078.wav, segment8
# genre_dataset\blues\blues.00078.wav, segment9
# genre_dataset\blues\blues.00078.wav, segment10
# genre_dataset\blues\blues.00079.wav, segment1
# genre_dataset\blues\blues.00079.wav, segment2
# genre_dataset\blues\blues.00079.wav, segment3
# genre_dataset\blues\blues.00079.wav, segment4
# genre_dataset\blues\blues.00079.wav, segment5
# genre_dataset\blues\blues.00079.wav, segment6
# genre_dataset\blues\blues.00079.wav, segment7
# genre_dataset\blues\blues.00079.wav, segment8
# genre_dataset\blues\blues.00079.wav, segment9
# genre_dataset\blues\blues.00079.wav, segment10
# genre_dataset\blues\blues.00080.wav, segment1
# genre_dataset\blues\blues.00080.wav, segment2
# genre_dataset\blues\blues.00080.wav, segment3
# genre_dataset\blues\blues.00080.wav, segment4
# genre_dataset\blues\blues.00080.wav, segment5
# genre_dataset\blues\blues.00080.wav, segment6
# genre_dataset\blues\blues.00080.wav, segment7
# genre_dataset\blues\blues.00080.wav, segment8
# genre_dataset\blues\blues.00080.wav, segment9
# genre_dataset\blues\blues.00080.wav, segment10
# genre_dataset\blues\blues.00081.wav, segment1
# genre_dataset\blues\blues.00081.wav, segment2
# genre_dataset\blues\blues.00081.wav, segment3
# genre_dataset\blues\blues.00081.wav, segment4
# genre_dataset\blues\blues.00081.wav, segment5
# genre_dataset\blues\blues.00081.wav, segment6
# genre_dataset\blues\blues.00081.wav, segment7
# genre_dataset\blues\blues.00081.wav, segment8
# genre_dataset\blues\blues.00081.wav, segment9
# genre_dataset\blues\blues.00081.wav, segment10
# genre_dataset\blues\blues.00082.wav, segment1
# genre_dataset\blues\blues.00082.wav, segment2
# genre_dataset\blues\blues.00082.wav, segment3
# genre_dataset\blues\blues.00082.wav, segment4
# genre_dataset\blues\blues.00082.wav, segment5
# genre_dataset\blues\blues.00082.wav, segment6
# genre_dataset\blues\blues.00082.wav, segment7
# genre_dataset\blues\blues.00082.wav, segment8
# genre_dataset\blues\blues.00082.wav, segment9
# genre_dataset\blues\blues.00082.wav, segment10
# genre_dataset\blues\blues.00083.wav, segment1
# genre_dataset\blues\blues.00083.wav, segment2
# genre_dataset\blues\blues.00083.wav, segment3
# genre_dataset\blues\blues.00083.wav, segment4
# genre_dataset\blues\blues.00083.wav, segment5
# genre_dataset\blues\blues.00083.wav, segment6
# genre_dataset\blues\blues.00083.wav, segment7
# genre_dataset\blues\blues.00083.wav, segment8
# genre_dataset\blues\blues.00083.wav, segment9
# genre_dataset\blues\blues.00083.wav, segment10
# genre_dataset\blues\blues.00084.wav, segment1
# genre_dataset\blues\blues.00084.wav, segment2
# genre_dataset\blues\blues.00084.wav, segment3
# genre_dataset\blues\blues.00084.wav, segment4
# genre_dataset\blues\blues.00084.wav, segment5
# genre_dataset\blues\blues.00084.wav, segment6
# genre_dataset\blues\blues.00084.wav, segment7
# genre_dataset\blues\blues.00084.wav, segment8
# genre_dataset\blues\blues.00084.wav, segment9
# genre_dataset\blues\blues.00084.wav, segment10
# genre_dataset\blues\blues.00085.wav, segment1
# genre_dataset\blues\blues.00085.wav, segment2
# genre_dataset\blues\blues.00085.wav, segment3
# genre_dataset\blues\blues.00085.wav, segment4
# genre_dataset\blues\blues.00085.wav, segment5
# genre_dataset\blues\blues.00085.wav, segment6
# genre_dataset\blues\blues.00085.wav, segment7
# genre_dataset\blues\blues.00085.wav, segment8
# genre_dataset\blues\blues.00085.wav, segment9
# genre_dataset\blues\blues.00085.wav, segment10
# genre_dataset\blues\blues.00086.wav, segment1
# genre_dataset\blues\blues.00086.wav, segment2
# genre_dataset\blues\blues.00086.wav, segment3
# genre_dataset\blues\blues.00086.wav, segment4
# genre_dataset\blues\blues.00086.wav, segment5
# genre_dataset\blues\blues.00086.wav, segment6
# genre_dataset\blues\blues.00086.wav, segment7
# genre_dataset\blues\blues.00086.wav, segment8
# genre_dataset\blues\blues.00086.wav, segment9
# genre_dataset\blues\blues.00086.wav, segment10
# genre_dataset\blues\blues.00087.wav, segment1
# genre_dataset\blues\blues.00087.wav, segment2
# genre_dataset\blues\blues.00087.wav, segment3
# genre_dataset\blues\blues.00087.wav, segment4
# genre_dataset\blues\blues.00087.wav, segment5
# genre_dataset\blues\blues.00087.wav, segment6
# genre_dataset\blues\blues.00087.wav, segment7
# genre_dataset\blues\blues.00087.wav, segment8
# genre_dataset\blues\blues.00087.wav, segment9
# genre_dataset\blues\blues.00087.wav, segment10
# genre_dataset\blues\blues.00088.wav, segment1
# genre_dataset\blues\blues.00088.wav, segment2
# genre_dataset\blues\blues.00088.wav, segment3
# genre_dataset\blues\blues.00088.wav, segment4
# genre_dataset\blues\blues.00088.wav, segment5
# genre_dataset\blues\blues.00088.wav, segment6
# genre_dataset\blues\blues.00088.wav, segment7
# genre_dataset\blues\blues.00088.wav, segment8
# genre_dataset\blues\blues.00088.wav, segment9
# genre_dataset\blues\blues.00088.wav, segment10
# genre_dataset\blues\blues.00089.wav, segment1
# genre_dataset\blues\blues.00089.wav, segment2
# genre_dataset\blues\blues.00089.wav, segment3
# genre_dataset\blues\blues.00089.wav, segment4
# genre_dataset\blues\blues.00089.wav, segment5
# genre_dataset\blues\blues.00089.wav, segment6
# genre_dataset\blues\blues.00089.wav, segment7
# genre_dataset\blues\blues.00089.wav, segment8
# genre_dataset\blues\blues.00089.wav, segment9
# genre_dataset\blues\blues.00089.wav, segment10
# genre_dataset\blues\blues.00090.wav, segment1
# genre_dataset\blues\blues.00090.wav, segment2
# genre_dataset\blues\blues.00090.wav, segment3
# genre_dataset\blues\blues.00090.wav, segment4
# genre_dataset\blues\blues.00090.wav, segment5
# genre_dataset\blues\blues.00090.wav, segment6
# genre_dataset\blues\blues.00090.wav, segment7
# genre_dataset\blues\blues.00090.wav, segment8
# genre_dataset\blues\blues.00090.wav, segment9
# genre_dataset\blues\blues.00090.wav, segment10
# genre_dataset\blues\blues.00091.wav, segment1
# genre_dataset\blues\blues.00091.wav, segment2
# genre_dataset\blues\blues.00091.wav, segment3
# genre_dataset\blues\blues.00091.wav, segment4
# genre_dataset\blues\blues.00091.wav, segment5
# genre_dataset\blues\blues.00091.wav, segment6
# genre_dataset\blues\blues.00091.wav, segment7
# genre_dataset\blues\blues.00091.wav, segment8
# genre_dataset\blues\blues.00091.wav, segment9
# genre_dataset\blues\blues.00091.wav, segment10
# genre_dataset\blues\blues.00092.wav, segment1
# genre_dataset\blues\blues.00092.wav, segment2
# genre_dataset\blues\blues.00092.wav, segment3
# genre_dataset\blues\blues.00092.wav, segment4
# genre_dataset\blues\blues.00092.wav, segment5
# genre_dataset\blues\blues.00092.wav, segment6
# genre_dataset\blues\blues.00092.wav, segment7
# genre_dataset\blues\blues.00092.wav, segment8
# genre_dataset\blues\blues.00092.wav, segment9
# genre_dataset\blues\blues.00092.wav, segment10
# genre_dataset\blues\blues.00093.wav, segment1
# genre_dataset\blues\blues.00093.wav, segment2
# genre_dataset\blues\blues.00093.wav, segment3
# genre_dataset\blues\blues.00093.wav, segment4
# genre_dataset\blues\blues.00093.wav, segment5
# genre_dataset\blues\blues.00093.wav, segment6
# genre_dataset\blues\blues.00093.wav, segment7
# genre_dataset\blues\blues.00093.wav, segment8
# genre_dataset\blues\blues.00093.wav, segment9
# genre_dataset\blues\blues.00093.wav, segment10
# genre_dataset\blues\blues.00094.wav, segment1
# genre_dataset\blues\blues.00094.wav, segment2
# genre_dataset\blues\blues.00094.wav, segment3
# genre_dataset\blues\blues.00094.wav, segment4
# genre_dataset\blues\blues.00094.wav, segment5
# genre_dataset\blues\blues.00094.wav, segment6
# genre_dataset\blues\blues.00094.wav, segment7
# genre_dataset\blues\blues.00094.wav, segment8
# genre_dataset\blues\blues.00094.wav, segment9
# genre_dataset\blues\blues.00094.wav, segment10
# genre_dataset\blues\blues.00095.wav, segment1
# genre_dataset\blues\blues.00095.wav, segment2
# genre_dataset\blues\blues.00095.wav, segment3
# genre_dataset\blues\blues.00095.wav, segment4
# genre_dataset\blues\blues.00095.wav, segment5
# genre_dataset\blues\blues.00095.wav, segment6
# genre_dataset\blues\blues.00095.wav, segment7
# genre_dataset\blues\blues.00095.wav, segment8
# genre_dataset\blues\blues.00095.wav, segment9
# genre_dataset\blues\blues.00095.wav, segment10
# genre_dataset\blues\blues.00096.wav, segment1
# genre_dataset\blues\blues.00096.wav, segment2
# genre_dataset\blues\blues.00096.wav, segment3
# genre_dataset\blues\blues.00096.wav, segment4
# genre_dataset\blues\blues.00096.wav, segment5
# genre_dataset\blues\blues.00096.wav, segment6
# genre_dataset\blues\blues.00096.wav, segment7
# genre_dataset\blues\blues.00096.wav, segment8
# genre_dataset\blues\blues.00096.wav, segment9
# genre_dataset\blues\blues.00096.wav, segment10
# genre_dataset\blues\blues.00097.wav, segment1
# genre_dataset\blues\blues.00097.wav, segment2
# genre_dataset\blues\blues.00097.wav, segment3
# genre_dataset\blues\blues.00097.wav, segment4
# genre_dataset\blues\blues.00097.wav, segment5
# genre_dataset\blues\blues.00097.wav, segment6
# genre_dataset\blues\blues.00097.wav, segment7
# genre_dataset\blues\blues.00097.wav, segment8
# genre_dataset\blues\blues.00097.wav, segment9
# genre_dataset\blues\blues.00097.wav, segment10
# genre_dataset\blues\blues.00098.wav, segment1
# genre_dataset\blues\blues.00098.wav, segment2
# genre_dataset\blues\blues.00098.wav, segment3
# genre_dataset\blues\blues.00098.wav, segment4
# genre_dataset\blues\blues.00098.wav, segment5
# genre_dataset\blues\blues.00098.wav, segment6
# genre_dataset\blues\blues.00098.wav, segment7
# genre_dataset\blues\blues.00098.wav, segment8
# genre_dataset\blues\blues.00098.wav, segment9
# genre_dataset\blues\blues.00098.wav, segment10
# genre_dataset\blues\blues.00099.wav, segment1
# genre_dataset\blues\blues.00099.wav, segment2
# genre_dataset\blues\blues.00099.wav, segment3
# genre_dataset\blues\blues.00099.wav, segment4
# genre_dataset\blues\blues.00099.wav, segment5
# genre_dataset\blues\blues.00099.wav, segment6
# genre_dataset\blues\blues.00099.wav, segment7
# genre_dataset\blues\blues.00099.wav, segment8
# genre_dataset\blues\blues.00099.wav, segment9
# genre_dataset\blues\blues.00099.wav, segment10
#
# Processing genre_dataset\classical
# genre_dataset\classical\classical.00000.wav, segment1
# genre_dataset\classical\classical.00000.wav, segment2
# genre_dataset\classical\classical.00000.wav, segment3
# genre_dataset\classical\classical.00000.wav, segment4
# genre_dataset\classical\classical.00000.wav, segment5
# genre_dataset\classical\classical.00000.wav, segment6
# genre_dataset\classical\classical.00000.wav, segment7
# genre_dataset\classical\classical.00000.wav, segment8
# genre_dataset\classical\classical.00000.wav, segment9
# genre_dataset\classical\classical.00000.wav, segment10
# genre_dataset\classical\classical.00001.wav, segment1
# genre_dataset\classical\classical.00001.wav, segment2
# genre_dataset\classical\classical.00001.wav, segment3
# genre_dataset\classical\classical.00001.wav, segment4
# genre_dataset\classical\classical.00001.wav, segment5
# genre_dataset\classical\classical.00001.wav, segment6
# genre_dataset\classical\classical.00001.wav, segment7
# genre_dataset\classical\classical.00001.wav, segment8
# genre_dataset\classical\classical.00001.wav, segment9
# genre_dataset\classical\classical.00001.wav, segment10
# genre_dataset\classical\classical.00002.wav, segment1
# genre_dataset\classical\classical.00002.wav, segment2
# genre_dataset\classical\classical.00002.wav, segment3
# genre_dataset\classical\classical.00002.wav, segment4
# genre_dataset\classical\classical.00002.wav, segment5
# genre_dataset\classical\classical.00002.wav, segment6
# genre_dataset\classical\classical.00002.wav, segment7
# genre_dataset\classical\classical.00002.wav, segment8
# genre_dataset\classical\classical.00002.wav, segment9
# genre_dataset\classical\classical.00002.wav, segment10
# genre_dataset\classical\classical.00003.wav, segment1
# genre_dataset\classical\classical.00003.wav, segment2
# genre_dataset\classical\classical.00003.wav, segment3
# ...
# genre_dataset\rock\rock.00063.wav, segment9
# genre_dataset\rock\rock.00063.wav, segment10
# genre_dataset\rock\rock.00064.wav, segment1
# genre_dataset\rock\rock.00064.wav, segment2
# genre_dataset\rock\rock.00064.wav, segment3
# genre_dataset\rock\rock.00064.wav, segment4
# genre_dataset\rock\rock.00064.wav, segment5
# genre_dataset\rock\rock.00064.wav, segment6
# genre_dataset\rock\rock.00064.wav, segment7
# genre_dataset\rock\rock.00064.wav, segment8
# genre_dataset\rock\rock.00064.wav, segment9
# genre_dataset\rock\rock.00064.wav, segment10
# genre_dataset\rock\rock.00065.wav, segment1
# genre_dataset\rock\rock.00065.wav, segment2
# genre_dataset\rock\rock.00065.wav, segment3
# genre_dataset\rock\rock.00065.wav, segment4
# genre_dataset\rock\rock.00065.wav, segment5
# genre_dataset\rock\rock.00065.wav, segment6
# genre_dataset\rock\rock.00065.wav, segment7
# genre_dataset\rock\rock.00065.wav, segment8
# genre_dataset\rock\rock.00065.wav, segment9
# genre_dataset\rock\rock.00065.wav, segment10
# genre_dataset\rock\rock.00066.wav, segment1
# genre_dataset\rock\rock.00066.wav, segment2
# genre_dataset\rock\rock.00066.wav, segment3
# genre_dataset\rock\rock.00066.wav, segment4
# genre_dataset\rock\rock.00066.wav, segment5
# genre_dataset\rock\rock.00066.wav, segment6
# genre_dataset\rock\rock.00066.wav, segment7
# genre_dataset\rock\rock.00066.wav, segment8
# genre_dataset\rock\rock.00066.wav, segment9
# genre_dataset\rock\rock.00066.wav, segment10
# genre_dataset\rock\rock.00067.wav, segment1
# genre_dataset\rock\rock.00067.wav, segment2
# genre_dataset\rock\rock.00067.wav, segment3
# genre_dataset\rock\rock.00067.wav, segment4
# genre_dataset\rock\rock.00067.wav, segment5
# genre_dataset\rock\rock.00067.wav, segment6
# genre_dataset\rock\rock.00067.wav, segment7
# genre_dataset\rock\rock.00067.wav, segment8
# genre_dataset\rock\rock.00067.wav, segment9
# genre_dataset\rock\rock.00067.wav, segment10
# genre_dataset\rock\rock.00068.wav, segment1
# genre_dataset\rock\rock.00068.wav, segment2
# genre_dataset\rock\rock.00068.wav, segment3
# genre_dataset\rock\rock.00068.wav, segment4
# genre_dataset\rock\rock.00068.wav, segment5
# genre_dataset\rock\rock.00068.wav, segment6
# genre_dataset\rock\rock.00068.wav, segment7
# genre_dataset\rock\rock.00068.wav, segment8
# genre_dataset\rock\rock.00068.wav, segment9
# genre_dataset\rock\rock.00068.wav, segment10
# genre_dataset\rock\rock.00069.wav, segment1
# genre_dataset\rock\rock.00069.wav, segment2
# genre_dataset\rock\rock.00069.wav, segment3
# genre_dataset\rock\rock.00069.wav, segment4
# genre_dataset\rock\rock.00069.wav, segment5
# genre_dataset\rock\rock.00069.wav, segment6
# genre_dataset\rock\rock.00069.wav, segment7
# genre_dataset\rock\rock.00069.wav, segment8
# genre_dataset\rock\rock.00069.wav, segment9
# genre_dataset\rock\rock.00069.wav, segment10
# genre_dataset\rock\rock.00070.wav, segment1
# genre_dataset\rock\rock.00070.wav, segment2
# genre_dataset\rock\rock.00070.wav, segment3
# genre_dataset\rock\rock.00070.wav, segment4
# genre_dataset\rock\rock.00070.wav, segment5
# genre_dataset\rock\rock.00070.wav, segment6
# genre_dataset\rock\rock.00070.wav, segment7
# genre_dataset\rock\rock.00070.wav, segment8
# genre_dataset\rock\rock.00070.wav, segment9
# genre_dataset\rock\rock.00070.wav, segment10
# genre_dataset\rock\rock.00071.wav, segment1
# genre_dataset\rock\rock.00071.wav, segment2
# genre_dataset\rock\rock.00071.wav, segment3
# genre_dataset\rock\rock.00071.wav, segment4
# genre_dataset\rock\rock.00071.wav, segment5
# genre_dataset\rock\rock.00071.wav, segment6
# genre_dataset\rock\rock.00071.wav, segment7
# genre_dataset\rock\rock.00071.wav, segment8
# genre_dataset\rock\rock.00071.wav, segment9
# genre_dataset\rock\rock.00071.wav, segment10
# genre_dataset\rock\rock.00072.wav, segment1
# genre_dataset\rock\rock.00072.wav, segment2
# genre_dataset\rock\rock.00072.wav, segment3
# genre_dataset\rock\rock.00072.wav, segment4
# genre_dataset\rock\rock.00072.wav, segment5
# genre_dataset\rock\rock.00072.wav, segment6
# genre_dataset\rock\rock.00072.wav, segment7
# genre_dataset\rock\rock.00072.wav, segment8
# genre_dataset\rock\rock.00072.wav, segment9
# genre_dataset\rock\rock.00072.wav, segment10
# genre_dataset\rock\rock.00073.wav, segment1
# genre_dataset\rock\rock.00073.wav, segment2
# genre_dataset\rock\rock.00073.wav, segment3
# genre_dataset\rock\rock.00073.wav, segment4
# genre_dataset\rock\rock.00073.wav, segment5
# genre_dataset\rock\rock.00073.wav, segment6
# genre_dataset\rock\rock.00073.wav, segment7
# genre_dataset\rock\rock.00073.wav, segment8
# genre_dataset\rock\rock.00073.wav, segment9
# genre_dataset\rock\rock.00073.wav, segment10
# genre_dataset\rock\rock.00074.wav, segment1
# genre_dataset\rock\rock.00074.wav, segment2
# genre_dataset\rock\rock.00074.wav, segment3
# genre_dataset\rock\rock.00074.wav, segment4
# genre_dataset\rock\rock.00074.wav, segment5
# genre_dataset\rock\rock.00074.wav, segment6
# genre_dataset\rock\rock.00074.wav, segment7
# genre_dataset\rock\rock.00074.wav, segment8
# genre_dataset\rock\rock.00074.wav, segment9
# genre_dataset\rock\rock.00074.wav, segment10
# genre_dataset\rock\rock.00075.wav, segment1
# genre_dataset\rock\rock.00075.wav, segment2
# genre_dataset\rock\rock.00075.wav, segment3
# genre_dataset\rock\rock.00075.wav, segment4
# genre_dataset\rock\rock.00075.wav, segment5
# genre_dataset\rock\rock.00075.wav, segment6
# genre_dataset\rock\rock.00075.wav, segment7
# genre_dataset\rock\rock.00075.wav, segment8
# genre_dataset\rock\rock.00075.wav, segment9
# genre_dataset\rock\rock.00075.wav, segment10
# genre_dataset\rock\rock.00076.wav, segment1
# genre_dataset\rock\rock.00076.wav, segment2
# genre_dataset\rock\rock.00076.wav, segment3
# genre_dataset\rock\rock.00076.wav, segment4
# genre_dataset\rock\rock.00076.wav, segment5
# genre_dataset\rock\rock.00076.wav, segment6
# genre_dataset\rock\rock.00076.wav, segment7
# genre_dataset\rock\rock.00076.wav, segment8
# genre_dataset\rock\rock.00076.wav, segment9
# genre_dataset\rock\rock.00076.wav, segment10
# genre_dataset\rock\rock.00077.wav, segment1
# genre_dataset\rock\rock.00077.wav, segment2
# genre_dataset\rock\rock.00077.wav, segment3
# genre_dataset\rock\rock.00077.wav, segment4
# genre_dataset\rock\rock.00077.wav, segment5
# genre_dataset\rock\rock.00077.wav, segment6
# genre_dataset\rock\rock.00077.wav, segment7
# genre_dataset\rock\rock.00077.wav, segment8
# genre_dataset\rock\rock.00077.wav, segment9
# genre_dataset\rock\rock.00077.wav, segment10
# genre_dataset\rock\rock.00078.wav, segment1
# genre_dataset\rock\rock.00078.wav, segment2
# genre_dataset\rock\rock.00078.wav, segment3
# genre_dataset\rock\rock.00078.wav, segment4
# genre_dataset\rock\rock.00078.wav, segment5
# genre_dataset\rock\rock.00078.wav, segment6
# genre_dataset\rock\rock.00078.wav, segment7
# genre_dataset\rock\rock.00078.wav, segment8
# genre_dataset\rock\rock.00078.wav, segment9
# genre_dataset\rock\rock.00078.wav, segment10
# genre_dataset\rock\rock.00079.wav, segment1
# genre_dataset\rock\rock.00079.wav, segment2
# genre_dataset\rock\rock.00079.wav, segment3
# genre_dataset\rock\rock.00079.wav, segment4
# genre_dataset\rock\rock.00079.wav, segment5
# genre_dataset\rock\rock.00079.wav, segment6
# genre_dataset\rock\rock.00079.wav, segment7
# genre_dataset\rock\rock.00079.wav, segment8
# genre_dataset\rock\rock.00079.wav, segment9
# genre_dataset\rock\rock.00079.wav, segment10
# genre_dataset\rock\rock.00080.wav, segment1
# genre_dataset\rock\rock.00080.wav, segment2
# genre_dataset\rock\rock.00080.wav, segment3
# genre_dataset\rock\rock.00080.wav, segment4
# genre_dataset\rock\rock.00080.wav, segment5
# genre_dataset\rock\rock.00080.wav, segment6
# genre_dataset\rock\rock.00080.wav, segment7
# genre_dataset\rock\rock.00080.wav, segment8
# genre_dataset\rock\rock.00080.wav, segment9
# genre_dataset\rock\rock.00080.wav, segment10
# genre_dataset\rock\rock.00081.wav, segment1
# genre_dataset\rock\rock.00081.wav, segment2
# genre_dataset\rock\rock.00081.wav, segment3
# genre_dataset\rock\rock.00081.wav, segment4
# genre_dataset\rock\rock.00081.wav, segment5
# genre_dataset\rock\rock.00081.wav, segment6
# genre_dataset\rock\rock.00081.wav, segment7
# genre_dataset\rock\rock.00081.wav, segment8
# genre_dataset\rock\rock.00081.wav, segment9
# genre_dataset\rock\rock.00081.wav, segment10
# genre_dataset\rock\rock.00082.wav, segment1
# genre_dataset\rock\rock.00082.wav, segment2
# genre_dataset\rock\rock.00082.wav, segment3
# genre_dataset\rock\rock.00082.wav, segment4
# genre_dataset\rock\rock.00082.wav, segment5
# genre_dataset\rock\rock.00082.wav, segment6
# genre_dataset\rock\rock.00082.wav, segment7
# genre_dataset\rock\rock.00082.wav, segment8
# genre_dataset\rock\rock.00082.wav, segment9
# genre_dataset\rock\rock.00082.wav, segment10
# genre_dataset\rock\rock.00083.wav, segment1
# genre_dataset\rock\rock.00083.wav, segment2
# genre_dataset\rock\rock.00083.wav, segment3
# genre_dataset\rock\rock.00083.wav, segment4
# genre_dataset\rock\rock.00083.wav, segment5
# genre_dataset\rock\rock.00083.wav, segment6
# genre_dataset\rock\rock.00083.wav, segment7
# genre_dataset\rock\rock.00083.wav, segment8
# genre_dataset\rock\rock.00083.wav, segment9
# genre_dataset\rock\rock.00083.wav, segment10
# genre_dataset\rock\rock.00084.wav, segment1
# genre_dataset\rock\rock.00084.wav, segment2
# genre_dataset\rock\rock.00084.wav, segment3
# genre_dataset\rock\rock.00084.wav, segment4
# genre_dataset\rock\rock.00084.wav, segment5
# genre_dataset\rock\rock.00084.wav, segment6
# genre_dataset\rock\rock.00084.wav, segment7
# genre_dataset\rock\rock.00084.wav, segment8
# genre_dataset\rock\rock.00084.wav, segment9
# genre_dataset\rock\rock.00084.wav, segment10
# genre_dataset\rock\rock.00085.wav, segment1
# genre_dataset\rock\rock.00085.wav, segment2
# genre_dataset\rock\rock.00085.wav, segment3
# genre_dataset\rock\rock.00085.wav, segment4
# genre_dataset\rock\rock.00085.wav, segment5
# genre_dataset\rock\rock.00085.wav, segment6
# genre_dataset\rock\rock.00085.wav, segment7
# genre_dataset\rock\rock.00085.wav, segment8
# genre_dataset\rock\rock.00085.wav, segment9
# genre_dataset\rock\rock.00085.wav, segment10
# genre_dataset\rock\rock.00086.wav, segment1
# genre_dataset\rock\rock.00086.wav, segment2
# genre_dataset\rock\rock.00086.wav, segment3
# genre_dataset\rock\rock.00086.wav, segment4
# genre_dataset\rock\rock.00086.wav, segment5
# genre_dataset\rock\rock.00086.wav, segment6
# genre_dataset\rock\rock.00086.wav, segment7
# genre_dataset\rock\rock.00086.wav, segment8
# genre_dataset\rock\rock.00086.wav, segment9
# genre_dataset\rock\rock.00086.wav, segment10
# genre_dataset\rock\rock.00087.wav, segment1
# genre_dataset\rock\rock.00087.wav, segment2
# genre_dataset\rock\rock.00087.wav, segment3
# genre_dataset\rock\rock.00087.wav, segment4
# genre_dataset\rock\rock.00087.wav, segment5
# genre_dataset\rock\rock.00087.wav, segment6
# genre_dataset\rock\rock.00087.wav, segment7
# genre_dataset\rock\rock.00087.wav, segment8
# genre_dataset\rock\rock.00087.wav, segment9
# genre_dataset\rock\rock.00087.wav, segment10
# genre_dataset\rock\rock.00088.wav, segment1
# genre_dataset\rock\rock.00088.wav, segment2
# genre_dataset\rock\rock.00088.wav, segment3
# genre_dataset\rock\rock.00088.wav, segment4
# genre_dataset\rock\rock.00088.wav, segment5
# genre_dataset\rock\rock.00088.wav, segment6
# genre_dataset\rock\rock.00088.wav, segment7
# genre_dataset\rock\rock.00088.wav, segment8
# genre_dataset\rock\rock.00088.wav, segment9
# genre_dataset\rock\rock.00088.wav, segment10
# genre_dataset\rock\rock.00089.wav, segment1
# genre_dataset\rock\rock.00089.wav, segment2
# genre_dataset\rock\rock.00089.wav, segment3
# genre_dataset\rock\rock.00089.wav, segment4
# genre_dataset\rock\rock.00089.wav, segment5
# genre_dataset\rock\rock.00089.wav, segment6
# genre_dataset\rock\rock.00089.wav, segment7
# genre_dataset\rock\rock.00089.wav, segment8
# genre_dataset\rock\rock.00089.wav, segment9
# genre_dataset\rock\rock.00089.wav, segment10
# genre_dataset\rock\rock.00090.wav, segment1
# genre_dataset\rock\rock.00090.wav, segment2
# genre_dataset\rock\rock.00090.wav, segment3
# genre_dataset\rock\rock.00090.wav, segment4
# genre_dataset\rock\rock.00090.wav, segment5
# genre_dataset\rock\rock.00090.wav, segment6
# genre_dataset\rock\rock.00090.wav, segment7
# genre_dataset\rock\rock.00090.wav, segment8
# genre_dataset\rock\rock.00090.wav, segment9
# genre_dataset\rock\rock.00090.wav, segment10
# genre_dataset\rock\rock.00091.wav, segment1
# genre_dataset\rock\rock.00091.wav, segment2
# genre_dataset\rock\rock.00091.wav, segment3
# genre_dataset\rock\rock.00091.wav, segment4
# genre_dataset\rock\rock.00091.wav, segment5
# genre_dataset\rock\rock.00091.wav, segment6
# genre_dataset\rock\rock.00091.wav, segment7
# genre_dataset\rock\rock.00091.wav, segment8
# genre_dataset\rock\rock.00091.wav, segment9
# genre_dataset\rock\rock.00091.wav, segment10
# genre_dataset\rock\rock.00092.wav, segment1
# genre_dataset\rock\rock.00092.wav, segment2
# genre_dataset\rock\rock.00092.wav, segment3
# genre_dataset\rock\rock.00092.wav, segment4
# genre_dataset\rock\rock.00092.wav, segment5
# genre_dataset\rock\rock.00092.wav, segment6
# genre_dataset\rock\rock.00092.wav, segment7
# genre_dataset\rock\rock.00092.wav, segment8
# genre_dataset\rock\rock.00092.wav, segment9
# genre_dataset\rock\rock.00092.wav, segment10
# genre_dataset\rock\rock.00093.wav, segment1
# genre_dataset\rock\rock.00093.wav, segment2
# genre_dataset\rock\rock.00093.wav, segment3
# genre_dataset\rock\rock.00093.wav, segment4
# genre_dataset\rock\rock.00093.wav, segment5
# genre_dataset\rock\rock.00093.wav, segment6
# genre_dataset\rock\rock.00093.wav, segment7
# genre_dataset\rock\rock.00093.wav, segment8
# genre_dataset\rock\rock.00093.wav, segment9
# genre_dataset\rock\rock.00093.wav, segment10
# genre_dataset\rock\rock.00094.wav, segment1
# genre_dataset\rock\rock.00094.wav, segment2
# genre_dataset\rock\rock.00094.wav, segment3
# genre_dataset\rock\rock.00094.wav, segment4
# genre_dataset\rock\rock.00094.wav, segment5
# genre_dataset\rock\rock.00094.wav, segment6
# genre_dataset\rock\rock.00094.wav, segment7
# genre_dataset\rock\rock.00094.wav, segment8
# genre_dataset\rock\rock.00094.wav, segment9
# genre_dataset\rock\rock.00094.wav, segment10
# genre_dataset\rock\rock.00095.wav, segment1
# genre_dataset\rock\rock.00095.wav, segment2
# genre_dataset\rock\rock.00095.wav, segment3
# genre_dataset\rock\rock.00095.wav, segment4
# genre_dataset\rock\rock.00095.wav, segment5
# genre_dataset\rock\rock.00095.wav, segment6
# genre_dataset\rock\rock.00095.wav, segment7
# genre_dataset\rock\rock.00095.wav, segment8
# genre_dataset\rock\rock.00095.wav, segment9
# genre_dataset\rock\rock.00095.wav, segment10
# genre_dataset\rock\rock.00096.wav, segment1
# genre_dataset\rock\rock.00096.wav, segment2
# genre_dataset\rock\rock.00096.wav, segment3
# genre_dataset\rock\rock.00096.wav, segment4
# genre_dataset\rock\rock.00096.wav, segment5
# genre_dataset\rock\rock.00096.wav, segment6
# genre_dataset\rock\rock.00096.wav, segment7
# genre_dataset\rock\rock.00096.wav, segment8
# genre_dataset\rock\rock.00096.wav, segment9
# genre_dataset\rock\rock.00096.wav, segment10
# genre_dataset\rock\rock.00097.wav, segment1
# genre_dataset\rock\rock.00097.wav, segment2
# genre_dataset\rock\rock.00097.wav, segment3
# genre_dataset\rock\rock.00097.wav, segment4
# genre_dataset\rock\rock.00097.wav, segment5
# genre_dataset\rock\rock.00097.wav, segment6
# genre_dataset\rock\rock.00097.wav, segment7
# genre_dataset\rock\rock.00097.wav, segment8
# genre_dataset\rock\rock.00097.wav, segment9
# genre_dataset\rock\rock.00097.wav, segment10
# genre_dataset\rock\rock.00098.wav, segment1
# genre_dataset\rock\rock.00098.wav, segment2
# genre_dataset\rock\rock.00098.wav, segment3
# genre_dataset\rock\rock.00098.wav, segment4
# genre_dataset\rock\rock.00098.wav, segment5
# genre_dataset\rock\rock.00098.wav, segment6
# genre_dataset\rock\rock.00098.wav, segment7
# genre_dataset\rock\rock.00098.wav, segment8
# genre_dataset\rock\rock.00098.wav, segment9
# genre_dataset\rock\rock.00098.wav, segment10
# genre_dataset\rock\rock.00099.wav, segment1
# genre_dataset\rock\rock.00099.wav, segment2
# genre_dataset\rock\rock.00099.wav, segment3
# genre_dataset\rock\rock.00099.wav, segment4
# genre_dataset\rock\rock.00099.wav, segment5
# genre_dataset\rock\rock.00099.wav, segment6
# genre_dataset\rock\rock.00099.wav, segment7
# genre_dataset\rock\rock.00099.wav, segment8
# genre_dataset\rock\rock.00099.wav, segment9
# genre_dataset\rock\rock.00099.wav, segment10

# %%
def load_data(data_path):

    with open(data_path, "r") as fp:
        data = json.load(fp)

    # convert lists to numpy arrays
    X = np.array(data["mfcc"])
    y = np.array(data["labels"])

    print("Data succesfully loaded!")

    return X, y

# %%
DATA_PATH = "data.json"
# load data
X, y = load_data(DATA_PATH)

# create train/test split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

# build network topology
model = keras.Sequential([
    
    # input layer
    keras.layers.Flatten(input_shape=(X.shape[1], X.shape[2])),

    # 1st dense layer
    keras.layers.Dense(512, activation='relu'),

    # 2nd dense layer
    keras.layers.Dense(256, activation='relu'),

    # 3rd dense layer
    keras.layers.Dense(64, activation='relu'),

    # output layer
    keras.layers.Dense(10, activation='softmax')
])

# compile model
optimiser = keras.optimizers.Adam(learning_rate=0.0001)
model.compile(optimizer=optimiser,
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

model.summary()

# train model
history = model.fit(X_train, y_train, validation_data=(X_test, y_test), batch_size=32, epochs=50)
# Out:
# Data succesfully loaded!
# WARNING:tensorflow:From C:\Users\harveyel17\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorflow\python\ops\init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten (Flatten)            (None, 1690)              0
# _________________________________________________________________
# dense (Dense)                (None, 512)               865792
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               131328
# _________________________________________________________________
# dense_2 (Dense)              (None, 64)                16448
# _________________________________________________________________
# dense_3 (Dense)              (None, 10)                650
# =================================================================
# Total params: 1,014,218
# Trainable params: 1,014,218
# Non-trainable params: 0
# _________________________________________________________________
# Train on 6990 samples, validate on 2996 samples
# Epoch 1/50
# 6990/6990 [==============================] - 2s 316us/sample - loss: 6.9829 - acc: 0.3020 - val_loss: 3.1990 - val_acc: 0.3615
# Epoch 2/50
# 6990/6990 [==============================] - 2s 327us/sample - loss: 2.5201 - acc: 0.3913 - val_loss: 2.4030 - val_acc: 0.3862
# Epoch 3/50
# 6990/6990 [==============================] - 2s 250us/sample - loss: 1.8774 - acc: 0.4564 - val_loss: 2.3324 - val_acc: 0.4009
# Epoch 4/50
# 6990/6990 [==============================] - 2s 285us/sample - loss: 1.5507 - acc: 0.5170 - val_loss: 2.0031 - val_acc: 0.4436
# Epoch 5/50
# 6990/6990 [==============================] - 2s 272us/sample - loss: 1.3249 - acc: 0.5714 - val_loss: 2.0678 - val_acc: 0.4509
# Epoch 6/50
# 6990/6990 [==============================] - 2s 250us/sample - loss: 1.1664 - acc: 0.6185 - val_loss: 2.0314 - val_acc: 0.4626
# Epoch 7/50
# 6990/6990 [==============================] - 2s 335us/sample - loss: 1.0169 - acc: 0.6536 - val_loss: 1.9160 - val_acc: 0.4793
# Epoch 8/50
# 6990/6990 [==============================] - 2s 312us/sample - loss: 0.9244 - acc: 0.6901 - val_loss: 1.9117 - val_acc: 0.5017
# Epoch 9/50
# 6990/6990 [==============================] - 3s 380us/sample - loss: 0.8162 - acc: 0.7270 - val_loss: 2.1350 - val_acc: 0.4780
# Epoch 10/50
# 6990/6990 [==============================] - 2s 346us/sample - loss: 0.7542 - acc: 0.7499 - val_loss: 1.9480 - val_acc: 0.5033
# Epoch 11/50
# 6990/6990 [==============================] - 2s 293us/sample - loss: 0.6772 - acc: 0.7715 - val_loss: 1.9860 - val_acc: 0.5177
# Epoch 12/50
# 6990/6990 [==============================] - 3s 375us/sample - loss: 0.6402 - acc: 0.7854 - val_loss: 1.9270 - val_acc: 0.5254
# Epoch 13/50
# 6990/6990 [==============================] - 2s 309us/sample - loss: 0.5501 - acc: 0.8132 - val_loss: 2.0628 - val_acc: 0.5200
# Epoch 14/50
# 6990/6990 [==============================] - 2s 260us/sample - loss: 0.4731 - acc: 0.8389 - val_loss: 1.9852 - val_acc: 0.5394
# Epoch 15/50
# 6990/6990 [==============================] - 2s 260us/sample - loss: 0.4523 - acc: 0.8535 - val_loss: 2.2062 - val_acc: 0.5003
# Epoch 16/50
# 6990/6990 [==============================] - 2s 272us/sample - loss: 0.4186 - acc: 0.8631 - val_loss: 1.9704 - val_acc: 0.5491
# Epoch 17/50
# 6990/6990 [==============================] - 3s 365us/sample - loss: 0.3820 - acc: 0.8710 - val_loss: 2.0346 - val_acc: 0.5601
# Epoch 18/50
# 6990/6990 [==============================] - 3s 361us/sample - loss: 0.3412 - acc: 0.8896 - val_loss: 2.0232 - val_acc: 0.5441
# Epoch 19/50
# 6990/6990 [==============================] - 2s 304us/sample - loss: 0.3333 - acc: 0.8897 - val_loss: 2.0485 - val_acc: 0.5638
# Epoch 20/50
# 6990/6990 [==============================] - 2s 282us/sample - loss: 0.2758 - acc: 0.9139 - val_loss: 2.0677 - val_acc: 0.5497
# Epoch 21/50
# 6990/6990 [==============================] - 2s 305us/sample - loss: 0.2404 - acc: 0.9220 - val_loss: 2.1391 - val_acc: 0.5567
# Epoch 22/50
# 6990/6990 [==============================] - 2s 260us/sample - loss: 0.2111 - acc: 0.9335 - val_loss: 2.1375 - val_acc: 0.5571
# Epoch 23/50
# 6990/6990 [==============================] - 2s 256us/sample - loss: 0.2371 - acc: 0.9240 - val_loss: 2.1171 - val_acc: 0.5734
# Epoch 24/50
# 6990/6990 [==============================] - 3s 446us/sample - loss: 0.2445 - acc: 0.9209 - val_loss: 2.1170 - val_acc: 0.5644
# Epoch 25/50
# 6990/6990 [==============================] - 3s 365us/sample - loss: 0.1693 - acc: 0.9485 - val_loss: 2.3626 - val_acc: 0.5704
# Epoch 26/50
# 6990/6990 [==============================] - 2s 291us/sample - loss: 0.1842 - acc: 0.9415 - val_loss: 2.1847 - val_acc: 0.5728
# Epoch 27/50
# 6990/6990 [==============================] - 3s 367us/sample - loss: 0.1498 - acc: 0.9541 - val_loss: 2.3231 - val_acc: 0.5678
# Epoch 28/50
# 6990/6990 [==============================] - 3s 385us/sample - loss: 0.1242 - acc: 0.9644 - val_loss: 2.2754 - val_acc: 0.5731
# Epoch 29/50
# 6990/6990 [==============================] - 2s 301us/sample - loss: 0.1859 - acc: 0.9419 - val_loss: 2.3787 - val_acc: 0.5738
# Epoch 30/50
# 6990/6990 [==============================] - 2s 282us/sample - loss: 0.1682 - acc: 0.9478 - val_loss: 2.4292 - val_acc: 0.5624
# Epoch 31/50
# 6990/6990 [==============================] - 2s 354us/sample - loss: 0.1337 - acc: 0.9588 - val_loss: 2.3819 - val_acc: 0.5721
# Epoch 32/50
# 6990/6990 [==============================] - 2s 284us/sample - loss: 0.1366 - acc: 0.9589 - val_loss: 2.4299 - val_acc: 0.5814
# Epoch 33/50
# 6990/6990 [==============================] - 2s 288us/sample - loss: 0.1356 - acc: 0.9574 - val_loss: 2.3842 - val_acc: 0.5741
# Epoch 34/50
# 6990/6990 [==============================] - 2s 299us/sample - loss: 0.1295 - acc: 0.9575 - val_loss: 2.4432 - val_acc: 0.5895
# Epoch 35/50
# 6990/6990 [==============================] - 2s 325us/sample - loss: 0.1164 - acc: 0.9622 - val_loss: 2.4461 - val_acc: 0.6028
# Epoch 36/50
# 6990/6990 [==============================] - 2s 313us/sample - loss: 0.1198 - acc: 0.9635 - val_loss: 2.4907 - val_acc: 0.6025
# Epoch 37/50
# 6990/6990 [==============================] - 3s 421us/sample - loss: 0.0669 - acc: 0.9810 - val_loss: 2.4880 - val_acc: 0.5915
# Epoch 38/50
# 6990/6990 [==============================] - 3s 485us/sample - loss: 0.0308 - acc: 0.9941 - val_loss: 2.4523 - val_acc: 0.6058
# Epoch 39/50
# 6990/6990 [==============================] - 2s 348us/sample - loss: 0.0618 - acc: 0.9808 - val_loss: 2.6848 - val_acc: 0.5691
# Epoch 40/50
# 6990/6990 [==============================] - 3s 399us/sample - loss: 0.3439 - acc: 0.8920 - val_loss: 2.8164 - val_acc: 0.5464
# Epoch 41/50
# 6990/6990 [==============================] - 2s 289us/sample - loss: 0.1653 - acc: 0.9498 - val_loss: 2.4079 - val_acc: 0.5961
# Epoch 42/50
# 6990/6990 [==============================] - 3s 372us/sample - loss: 0.0764 - acc: 0.9778 - val_loss: 2.5830 - val_acc: 0.5848
# Epoch 43/50
# 6990/6990 [==============================] - 3s 379us/sample - loss: 0.0703 - acc: 0.9818 - val_loss: 2.5422 - val_acc: 0.5871
# Epoch 44/50
# 6990/6990 [==============================] - 3s 487us/sample - loss: 0.0260 - acc: 0.9934 - val_loss: 2.5063 - val_acc: 0.6088
# Epoch 45/50
# 6990/6990 [==============================] - 2s 300us/sample - loss: 0.0248 - acc: 0.9951 - val_loss: 2.5875 - val_acc: 0.6048
# Epoch 46/50
# 6990/6990 [==============================] - 3s 362us/sample - loss: 0.0750 - acc: 0.9790 - val_loss: 2.8065 - val_acc: 0.5774
# Epoch 47/50
# 6990/6990 [==============================] - 2s 297us/sample - loss: 0.2647 - acc: 0.9170 - val_loss: 3.1420 - val_acc: 0.5564
# Epoch 48/50
# 6990/6990 [==============================] - 2s 276us/sample - loss: 0.1212 - acc: 0.9625 - val_loss: 2.6523 - val_acc: 0.5985
# Epoch 49/50
# 6990/6990 [==============================] - 2s 240us/sample - loss: 0.0471 - acc: 0.9870 - val_loss: 2.5176 - val_acc: 0.6038
# Epoch 50/50
# 6990/6990 [==============================] - 2s 251us/sample - loss: 0.0148 - acc: 0.9971 - val_loss: 2.6161 - val_acc: 0.6132
